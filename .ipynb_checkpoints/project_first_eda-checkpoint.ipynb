# %%
import pandas as pd

bom = pd.read_excel('BOM_11_2017.xlsx')
bom.head(20)
# Out:
#    Finished Part  Pos Component Part  Qty  ME      Formel  Faktor  ME brutto
# 0           1014   10        7379/10    1  pc  No Formula     1.0          1
# 1           1014   20           4034    1  pc  No Formula     1.0          1
# 2           1014   30           3086    1  pc  No Formula     1.0          1
# 3           1014   40           4002    1  pc  No Formula     1.0          1
# 4           1014   50        4066/09    1  pc  No Formula     1.0          1
# 5           1014   60           4072    1  pc  No Formula     1.0          1
# 6           1014   70           4145    1  pc  No Formula     1.0          1
# 7           1014   80           4241    1  pc  No Formula     1.0          1
# 8           1014   90        4430/25    1  pc  No Formula     1.0          1
# 9           1014  100        4515/32    1  pc  No Formula     1.0          1
# 10          1014  110        4582/26    1  pc  No Formula     1.0          1
# ...

# %%
bom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 8 columns):
# Finished Part     4269 non-null object
# Pos               4269 non-null int64
# Component Part    4269 non-null object
# Qty               4269 non-null int64
# ME                4269 non-null object
# Formel            4269 non-null object
# Faktor            4269 non-null float64
# ME brutto         4269 non-null int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 266.9+ KB

# %%
inventory = pd.read_excel('Inventory_Nov_2017.xlsx')
inventory.head(20)
# Out:
#     Part Number arch                Description  Unit Price Total Value  \
# 0    03102751CC  NaN       Clear Cover for 2751       0.725      145.02
# 1    03119990-1  NaN         Small wall Display       0.000           0
# 2    03119990-3  NaN              Floor Display       0.000           0
# 3    03138625FC  NaN     Folded Carton for 8625       1.570       37.68
# 4   0314FT365-4  NaN        Flock Tray Chai Dao       0.380       60.78
# 5   0314FT365-5  NaN  Flock Tray Epicure 365x80       0.347       13.86
# 6      04000335  NaN  Klarsichtverpackung Gr. 5       1.110      1309.8
# 7      04149602  NaN      Einsatz schwarz Gr. 6       0.863      503.76
# 8   04164010/07  NaN                Knife Guard       0.111       11.14
# 9   04164022/08  NaN                Knife Guard       0.111        55.7
# 10  04164030/07  NaN                Knife Guard       0.111       22.28
# 11  04164040/12  NaN                Knife Guard       0.111       11.14
# ...

# %%
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196083 entries, 0 to 196082
# Data columns (total 30 columns):
# Part Number         196082 non-null object
# arch                3198 non-null object
# Description         196082 non-null object
# Unit Price          196082 non-null float64
# Total Value         196083 non-null object
# On-Hand             196082 non-null float64
# Sichbest            196082 non-null float64
# MeldBest            196082 non-null float64
# BestME              183230 non-null float64
# LO1                 196082 non-null float64
# BestStich           196082 non-null float64
# TGrp                196082 non-null float64
# Lagerplatz          11910 non-null object
# Lagerplatz Stamm    117327 non-null object
# Selection           37268 non-null object
# Lagerort            195750 non-null object
# PrdLn               196082 non-null object
# Stichtag            196082 non-null datetime64[ns]
# Month               196082 non-null float64
# ...

# %%
sales = pd.read_excel('Sales and Inventory 2015-2017 V3.xlsx')
sales.head(20)
# Out:
#                 $ Sales           Unnamed: 1           Unnamed: 2  \
# 0           Item Number  2017-01-01 00:00:00  2017-02-01 00:00:00
# 1                9718-6                33412              31871.1
# 2                  7417               114266               117165
# 3             4582-7/20               147635                34820
# 4                  9468               122946              42971.8
# 5                  9312              97490.7              97672.1
# 6                  9718              86500.5              90558.1
# 7                8944-1              52475.1              95600.8
# 8                  8347              50518.7              64521.2
# 9               9718-17                57600                57600
# 10                 1777              35556.4              66260.7
# 11               9468-6                30243                10674
# 12               9740-1              37772.3              12345.6
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1341 entries, 0 to 1340
# Data columns (total 35 columns):
# $ Sales           1340 non-null object
# Unnamed: 1        1338 non-null object
# Unnamed: 2        1338 non-null object
# Unnamed: 3        1338 non-null object
# Unnamed: 4        1338 non-null object
# Unnamed: 5        1338 non-null object
# Unnamed: 6        1338 non-null object
# Unnamed: 7        1338 non-null object
# Unnamed: 8        1338 non-null object
# Unnamed: 9        1338 non-null object
# Unnamed: 10       1338 non-null object
# Unnamed: 11       1338 non-null object
# Unnamed: 12       1338 non-null object
# Inventory         1338 non-null object
# Unnamed: 14       1110 non-null object
# Unnamed: 15       1110 non-null object
# Unnamed: 16       1173 non-null object
# Unnamed: 17       1173 non-null object
# Unnamed: 18       1173 non-null object
# Unnamed: 19       1173 non-null object
# Unnamed: 20       1173 non-null object
# ...

# %%
monthly = pd.read_excel('Sales by part by month.xlsx')
monthly.head(20)
# Out:
#             Unnamed: 0     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0   Sum of Final Price  Column Labels        NaN        NaN        NaN
# 1           Row Labels        2012-04    2012-05    2012-06    2012-07
# 2               400000            NaN        NaN        NaN        NaN
# 3          0300ST365-1            NaN        NaN        NaN        NaN
# 4            0311HT265            NaN        NaN        NaN        NaN
# 5            0311HT320            NaN        NaN        NaN        NaN
# 6           03139731BT            NaN        NaN        NaN        NaN
# 7          03139800MPK            NaN        NaN        NaN        NaN
# 8            0313FC320            NaN        NaN        NaN        NaN
# 9            0313FC365            NaN        NaN        NaN        NaN
# 10          03149731CC            NaN        NaN        NaN        NaN
# 11          03149731FT            NaN        NaN        NaN        NaN
# ...

# %%
monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128786 entries, 0 to 128785
# Data columns (total 70 columns):
# Unnamed: 0     128786 non-null object
# Unnamed: 1     5714 non-null object
# Unnamed: 2     5773 non-null object
# Unnamed: 3     6206 non-null object
# Unnamed: 4     6876 non-null object
# Unnamed: 5     7399 non-null object
# Unnamed: 6     8822 non-null object
# Unnamed: 7     9056 non-null object
# Unnamed: 8     8419 non-null object
# Unnamed: 9     7824 non-null object
# Unnamed: 10    8266 non-null object
# Unnamed: 11    6946 non-null object
# Unnamed: 12    7799 non-null object
# Unnamed: 13    6492 non-null object
# Unnamed: 14    6887 non-null object
# Unnamed: 15    6564 non-null object
# Unnamed: 16    7171 non-null object
# Unnamed: 17    7976 non-null object
# Unnamed: 18    9282 non-null object
# Unnamed: 19    11214 non-null object
# Unnamed: 20    8021 non-null object
# Unnamed: 21    9108 non-null object
# Unnamed: 22    7754 non-null object
# ...

# %%
invoices = pd.read_excel('Sales Orders vs Invoices Ver 2.xlsx')
invoices.head(20)
# Out:
#     CRO Number  Line      Part    Part Description 1  Quantity  Unit Price  \
# 0   11031510.0   1.0    2267-5  17 Slot Bamboo Knife         1         0.0
# 1   11031590.0   1.0      4022  Gourmet 3'' Spear Po         1         0.0
# 2   11031535.0   1.0      4051   XXXSilverpoint II 4         1         0.0
# 3   11031600.0   1.0      4183   Classic 7'' Santoku         1         0.0
# 4   11031704.0   1.0      8777    Herb Shear BLISTER         1         0.0
# 5   11031742.0   1.0    5558-1  Black Come Apart Kit         1         0.0
# 6   11030099.0   1.0      4034  Gourmet 2 1/4'' Peel         1         0.0
# 7   11031050.0   1.0   4596/20  Classic Ikon 8'' Coo         1         0.0
# 8   11031828.0   1.0      2263   13 Slot Knife Block         1         0.0
# 9   11031857.0   1.0      2408   Wood Chest Box 8 pc         1         0.0
# 10  11031825.0   1.0      2513  Walnut Box 2 pc Carv         1         0.0
# ...

# %%
invoices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462115 entries, 0 to 462114
# Data columns (total 22 columns):
# CRO Number                       460061 non-null float64
# Line                             462115 non-null float64
# Part                             462115 non-null object
# Part Description 1               462115 non-null object
# Quantity                         462115 non-null int64
# Unit Price                       462115 non-null float64
# Final Price                      462115 non-null float64
# Doc Date                         462115 non-null datetime64[ns]
# Doc No.                          462115 non-null int64
# Product Line                     462115 non-null int64
# Customer                         462115 non-null int64
# ShippingType                     462115 non-null int64
# Weight                           462115 non-null float64
# Val                              462115 non-null object
# ...
